# %% [markdown]
# <a href="https://colab.research.google.com/github/SofiaEstudiante/CURSO_FES_Progamacion/blob/main/Primer_ejercicio_de_programaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# clase 1

# %%
#para escribir es entre comillas""
#para numero no se ocupa

# %%
#OPERACIONES BASICAS DE PROGRAMACION
N1= 6
N2= 10
Suma=N1 + N2
Resta=N1 + N2
Division=N1 / N2
Multiplicacion=N1 * N2
Operacion= (N1 + N2) + (N1 / N2)
Potencia= N1 **  N2 #el doble asterico es para potencia

print("El valor de la operacion es igual a:", Operacion)
print("El valor de la suma es igual a:", Suma)
print("El valor de la resta es igual a:", Resta)
print("El valor de la division es igual a:", Division)
print("El valor de la multiplicacion es igual a:", Multiplicacion)
print("El valor de la potencia es igual a:", Potencia)
# Out:
# El valor de la operacion es igual a: 16.6
# El valor de la suma es igual a: 16
# El valor de la resta es igual a: 16
# El valor de la division es igual a: 0.6
# El valor de la multiplicacion es igual a: 60
# El valor de la potencia es igual a: 60466176

# %%
#Operadores aritmeticos
a= 2
b= 4
resultado=a / b
print(resultado)
# Out:
# 0.5

# %%
#MODULO ES EL RESIDUO DE LA DIVISION
a= 10
b= 3
resultado= a % b
print(resultado)
# Out:
# 1

# %%
#COMO SACAR UNA Raiz
a= 25**0.5  #nuestra raiz siempre se eleva en un (1/2) o 0.5
print(a)
# Out:
# 5.0

# %%
#otra forma de calc la raiz

a= pow(25,0.5)
print(a)
# Out:
# 5.0

# %%
import numpy as np #Liberia para calcular raices
a=np.sqrt(25)
print(a)
# Out:
# 5.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Jerarquia de operaciones

#Parentesis, Potencias Y Raices

Resultado=((15-13)*(31-26))+ 18 //(1 + 4 * 2)

#NUMERO ENTERO ES dos diagonales // (redondeada) y fraccion es /
print("El resultado de la operacion es igual a", Resultado)
# Out:
# El resultado de la operacion es igual a 12

# %% [markdown]
# OPERADORES RELACIONALES
#
# ![racional.jpg](data:image/jpeg;base64,...)

# %%
#Operadores relacionales
Operador= 10  >  20
Operador2= 10  == 20
print(Operador2)
# Out:
# False

# %%
a=10
b=5
c=6
operacion=(a+c)<b
print(operacion)
# Out:
# False

# %%
#Operadores logicos
a=10
b=15
c=20
resultado=((a>b) and (b<c))
resultado2=((a<b) and (b<c))
print(resultado)
print(resultado2)
# Out:
# False
# True

# %%
#operadores de asignacion
a=1
a +=3 #asignacion suma
a -=1 #asignacion resta
a *=3 #asignacion multiplicacion
a **=2 #asignacion division

print(a)
# Out:
# 81

# %%
#salida de datos
Nombre= "Sofia"
altura= 1.60
print("Tu nombre es",Nombre)
print("Tu altura es",altura)

#utilizamos format
print("Tu nombre es: {} y tu altura es: {}".format(Nombre,altura))

#esta es la forma que utilizaremos
print(f"Hola:{Nombre} tu Altura es:{altura} metros")
# Out:
# Tu nombre es Sofia
# Tu altura es 1.6
# Tu nombre es: Sofia y tu altura es: 1.6
# Hola:Sofia tu Altura es:1.6 metros

# %%
#entrada de datos
#input es una duncion que se utiliza para pedir datos al usurio
nombre= input("Digite su nombre")
print(f"Buenas noches {nombre}")

# %%
numero= input("Digite un numero")

print(f"El numero es: {numero}")

#valor de tipo

numero= float(input("Digite un numero"))

print(f"El numero es: {numero*5}")

# %%
#funciones integradas

#convertir de valor numerio a cadena
#n= str(10)
#print(n)

#De enteros a binarios
#n= bin(10)
#print(n)

#n= abs(40)
#print(n)

#n=lean (sirve para contar cuantos caracteres hay)
#print(n)

# %% [markdown]
# SUMAR LOS PRIMEROS NUMEROS
# ![formula.jpg](data:image/jpeg;base64,...)

# %%
#
